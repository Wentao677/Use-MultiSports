# %%
import torch
import numpy as np
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/004.Diabetes
# Out:
# /content/drive/MyDrive/004.Diabetes

# %%
# !ls
# Out:
# diabetes.csv  main.py  names_test.csv  names_train.csv

# %%
# !python main.py
# Out:
# 0 0 0.6734203100204468
# 0 1 0.6728324294090271
# 0 2 0.677582859992981
# 0 3 0.6820309162139893
# 0 4 0.6722248196601868
# 0 5 0.6673678755760193
# 0 6 0.6519308686256409
# 0 7 0.6611344814300537
# 0 8 0.6707414388656616
# 0 9 0.6651492714881897
# 0 10 0.7024646997451782
# 0 11 0.6593570113182068
# 0 12 0.6647368669509888
# 0 13 0.6809355616569519
# 0 14 0.6751144528388977
# 0 15 0.6913837194442749
# 0 16 0.6302112936973572
# 0 17 0.6802060604095459
# 0 18 0.6510061025619507
# 0 19 0.668046772480011
# 0 20 0.6617026925086975
# 0 21 0.6609704494476318
# 0 22 0.6921054124832153
# 0 23 0.6940793395042419
# 1 0 0.6736685633659363
# 1 1 0.6422677636146545
# 1 2 0.6602165699005127
# 1 3 0.6854357123374939
# 1 4 0.6661983728408813
# 1 5 0.6531656384468079
# 1 6 0.685732364654541
# 1 7 0.6793537139892578
# 1 8 0.6790103912353516
# 1 9 0.6454670429229736
# 1 10 0.6581770181655884
# 1 11 0.6511341333389282
# 1 12 0.6505153179168701
# 1 13 0.685260534286499
# 1 14 0.6853716969490051
# ...
