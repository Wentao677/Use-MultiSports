# %% [markdown]
# 一.安装colab没有安装的包
# - 先在视图里面硬件加速器换上GPU
# - 挂载google drive
# - （下面的cell要运行两次，第一次会出来一个提示让你restart，点一下他，然后再重新点一下运行键）

# %%
# !pip install transformers
# !pip install pillow==9.1.0

# %% [markdown]
# - 检查一下环境是不是都配好了

# %%
import torch
import numpy
import transformers
import tqdm
import matplotlib
import PIL
import sklearn

print("torch version:", torch.__version__)
print("numpy version:", numpy.__version__)
print("transformers version:", transformers.__version__)
print("tqdm version:", tqdm.__version__)
print("matplotlib version:", matplotlib.__version__)
print("pillow version:", PIL.__version__)
print("scikit-learn version:", sklearn.__version__)
# Out:
# torch version: 2.0.1+cu118
# numpy version: 1.22.4
# transformers version: 4.30.2
# tqdm version: 4.65.0
# matplotlib version: 3.7.1
# pillow version: 9.1.0
# scikit-learn version: 1.2.2

# %% [markdown]
# 二. 把工作目录切换到以下路径

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Image_Classfiation_Coil20-master
# Out:
# /content/drive/MyDrive/Image_Classfiation_Coil20-master

# %%
! ls
# Out:
# config.py  dataset  main.py   __pycache__  requirements.txt
# data.py    logs     model.py  README.md

# %% [markdown]
# 三. 运行（运行前先自己在当前文件夹创立一个叫result的文件夹）

# %%
# !python main.py
# Out:
# > cuda memory allocated: 24025088
# > training arguments:
# >>> num_classes: 20
# >>> model_name: GoogleNet
# >>> train_batch_size: 32
# >>> test_batch_size: 32
# >>> num_epoch: 50
# >>> lr: 0.0001
# >>> weight_decay: 0.01
# >>> device: cuda
# >>> backend: False
# >>> workers: 0
# >>> timestamp: 1687832881436
# >>> index: 0
# >>> log_name: GoogleNet_23-06-27_02-28-01.log
# inputs.0.weight torch.Size([64, 1, 17, 17])
# inputs.0.bias torch.Size([64])
# inputs.3.weight torch.Size([64, 64, 1, 1])
# inputs.3.bias torch.Size([64])
# inputs.4.weight torch.Size([192, 64, 3, 3])
# inputs.4.bias torch.Size([192])
# block1.0.branch1.conv.weight torch.Size([64, 192, 1, 1])
# block1.0.branch1.conv.bias torch.Size([64])
# block1.0.branch2.0.conv.weight torch.Size([96, 192, 1, 1])
# block1.0.branch2.0.conv.bias torch.Size([96])
# block1.0.branch2.1.conv.weight torch.Size([128, 96, 3, 3])
# block1.0.branch2.1.conv.bias torch.Size([128])
# block1.0.branch3.0.conv.weight torch.Size([16, 192, 1, 1])
# block1.0.branch3.0.conv.bias torch.Size([16])
# block1.0.branch3.1.conv.weight torch.Size([32, 16, 5, 5])
# block1.0.branch3.1.conv.bias torch.Size([32])
# block1.0.branch4.1.conv.weight torch.Size([32, 192, 1, 1])
# block1.0.branch4.1.conv.bias torch.Size([32])
# block1.1.branch1.conv.weight torch.Size([128, 256, 1, 1])
# block1.1.branch1.conv.bias torch.Size([128])
# block1.1.branch2.0.conv.weight torch.Size([128, 256, 1, 1])
# block1.1.branch2.0.conv.bias torch.Size([128])
# block1.1.branch2.1.conv.weight torch.Size([192, 128, 3, 3])
# block1.1.branch2.1.conv.bias torch.Size([192])
# block1.1.branch3.0.conv.weight torch.Size([32, 256, 1, 1])
# block1.1.branch3.0.conv.bias torch.Size([32])
# block1.1.branch3.1.conv.weight torch.Size([96, 32, 5, 5])
# block1.1.branch3.1.conv.bias torch.Size([96])
# block1.1.branch4.1.conv.weight torch.Size([64, 256, 1, 1])
# block1.1.branch4.1.conv.bias torch.Size([64])
# block2.0.branch1.conv.weight torch.Size([192, 480, 1, 1])
# block2.0.branch1.conv.bias torch.Size([192])
# block2.0.branch2.0.conv.weight torch.Size([96, 480, 1, 1])
# block2.0.branch2.0.conv.bias torch.Size([96])
# block2.0.branch2.1.conv.weight torch.Size([208, 96, 3, 3])
# block2.0.branch2.1.conv.bias torch.Size([208])
# block2.0.branch3.0.conv.weight torch.Size([16, 480, 1, 1])
# block2.0.branch3.0.conv.bias torch.Size([16])
# block2.0.branch3.1.conv.weight torch.Size([48, 16, 5, 5])
# block2.0.branch3.1.conv.bias torch.Size([48])
# block2.0.branch4.1.conv.weight torch.Size([64, 480, 1, 1])
# block2.0.branch4.1.conv.bias torch.Size([64])
# block2.1.branch1.conv.weight torch.Size([160, 512, 1, 1])
# block2.1.branch1.conv.bias torch.Size([160])
# block2.1.branch2.0.conv.weight torch.Size([112, 512, 1, 1])
# block2.1.branch2.0.conv.bias torch.Size([112])
# block2.1.branch2.1.conv.weight torch.Size([224, 112, 3, 3])
# block2.1.branch2.1.conv.bias torch.Size([224])
# block2.1.branch3.0.conv.weight torch.Size([24, 512, 1, 1])
# block2.1.branch3.0.conv.bias torch.Size([24])
# block2.1.branch3.1.conv.weight torch.Size([64, 24, 5, 5])
# block2.1.branch3.1.conv.bias torch.Size([64])
# block2.1.branch4.1.conv.weight torch.Size([64, 512, 1, 1])
# block2.1.branch4.1.conv.bias torch.Size([64])
# block2.2.branch1.conv.weight torch.Size([128, 512, 1, 1])
# block2.2.branch1.conv.bias torch.Size([128])
# block2.2.branch2.0.conv.weight torch.Size([128, 512, 1, 1])
# block2.2.branch2.0.conv.bias torch.Size([128])
# block2.2.branch2.1.conv.weight torch.Size([256, 128, 3, 3])
# block2.2.branch2.1.conv.bias torch.Size([256])
# block2.2.branch3.0.conv.weight torch.Size([24, 512, 1, 1])
# block2.2.branch3.0.conv.bias torch.Size([24])
# block2.2.branch3.1.conv.weight torch.Size([64, 24, 5, 5])
# block2.2.branch3.1.conv.bias torch.Size([64])
# block2.2.branch4.1.conv.weight torch.Size([64, 512, 1, 1])
# block2.2.branch4.1.conv.bias torch.Size([64])
# block2.3.branch1.conv.weight torch.Size([112, 512, 1, 1])
# block2.3.branch1.conv.bias torch.Size([112])
# block2.3.branch2.0.conv.weight torch.Size([144, 512, 1, 1])
# block2.3.branch2.0.conv.bias torch.Size([144])
# block2.3.branch2.1.conv.weight torch.Size([288, 144, 3, 3])
# block2.3.branch2.1.conv.bias torch.Size([288])
# block2.3.branch3.0.conv.weight torch.Size([32, 512, 1, 1])
# block2.3.branch3.0.conv.bias torch.Size([32])
# block2.3.branch3.1.conv.weight torch.Size([64, 32, 5, 5])
# block2.3.branch3.1.conv.bias torch.Size([64])
# block2.3.branch4.1.conv.weight torch.Size([64, 512, 1, 1])
# block2.3.branch4.1.conv.bias torch.Size([64])
# block2.4.branch1.conv.weight torch.Size([256, 528, 1, 1])
# block2.4.branch1.conv.bias torch.Size([256])
# block2.4.branch2.0.conv.weight torch.Size([160, 528, 1, 1])
# block2.4.branch2.0.conv.bias torch.Size([160])
# block2.4.branch2.1.conv.weight torch.Size([320, 160, 3, 3])
# block2.4.branch2.1.conv.bias torch.Size([320])
# block2.4.branch3.0.conv.weight torch.Size([32, 528, 1, 1])
# block2.4.branch3.0.conv.bias torch.Size([32])
# block2.4.branch3.1.conv.weight torch.Size([128, 32, 5, 5])
# block2.4.branch3.1.conv.bias torch.Size([128])
# block2.4.branch4.1.conv.weight torch.Size([128, 528, 1, 1])
# block2.4.branch4.1.conv.bias torch.Size([128])
# block3.0.branch1.conv.weight torch.Size([256, 832, 1, 1])
# block3.0.branch1.conv.bias torch.Size([256])
# block3.0.branch2.0.conv.weight torch.Size([160, 832, 1, 1])
# block3.0.branch2.0.conv.bias torch.Size([160])
# block3.0.branch2.1.conv.weight torch.Size([320, 160, 3, 3])
# block3.0.branch2.1.conv.bias torch.Size([320])
# block3.0.branch3.0.conv.weight torch.Size([32, 832, 1, 1])
# block3.0.branch3.0.conv.bias torch.Size([32])
# block3.0.branch3.1.conv.weight torch.Size([128, 32, 5, 5])
# block3.0.branch3.1.conv.bias torch.Size([128])
# block3.0.branch4.1.conv.weight torch.Size([128, 832, 1, 1])
# block3.0.branch4.1.conv.bias torch.Size([128])
# block3.1.branch1.conv.weight torch.Size([384, 832, 1, 1])
# block3.1.branch1.conv.bias torch.Size([384])
# block3.1.branch2.0.conv.weight torch.Size([192, 832, 1, 1])
# block3.1.branch2.0.conv.bias torch.Size([192])
# block3.1.branch2.1.conv.weight torch.Size([384, 192, 3, 3])
# block3.1.branch2.1.conv.bias torch.Size([384])
# block3.1.branch3.0.conv.weight torch.Size([48, 832, 1, 1])
# block3.1.branch3.0.conv.bias torch.Size([48])
# block3.1.branch3.1.conv.weight torch.Size([128, 48, 5, 5])
# block3.1.branch3.1.conv.bias torch.Size([128])
# block3.1.branch4.1.conv.weight torch.Size([128, 832, 1, 1])
# block3.1.branch4.1.conv.bias torch.Size([128])
# outputs.1.weight torch.Size([20, 1024])
# outputs.1.bias torch.Size([20])
# 100% 41/41 [00:04<00:00,  8.69it/s]
# 100% 5/5 [00:00<00:00, 33.39it/s]
# 1/50 - 2.00%
# [train] loss: 2.9968, acc: 4.09
# [test] loss: 2.9985, acc: 4.86
# 100% 41/41 [00:04<00:00,  9.90it/s]
# 100% 5/5 [00:00<00:00, 33.03it/s]
# 2/50 - 4.00%
# [train] loss: 2.9965, acc: 4.78
# [test] loss: 2.9991, acc: 2.78
# 100% 41/41 [00:04<00:00,  9.88it/s]
# 100% 5/5 [00:00<00:00, 32.34it/s]
# 3/50 - 6.00%
# [train] loss: 2.9965, acc: 4.86
# [test] loss: 2.9990, acc: 2.78
# 100% 41/41 [00:04<00:00,  9.79it/s]
# 100% 5/5 [00:00<00:00, 33.19it/s]
# 4/50 - 8.00%
# [train] loss: 2.9960, acc: 5.17
# [test] loss: 2.9998, acc: 2.78
# 100% 41/41 [00:04<00:00,  9.73it/s]
# 100% 5/5 [00:00<00:00, 32.94it/s]
# 5/50 - 10.00%
# [train] loss: 2.9959, acc: 5.09
# [test] loss: 2.9999, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.68it/s]
# 100% 5/5 [00:00<00:00, 31.95it/s]
# 6/50 - 12.00%
# [train] loss: 2.9963, acc: 4.78
# [test] loss: 3.0005, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.64it/s]
# 100% 5/5 [00:00<00:00, 32.64it/s]
# 7/50 - 14.00%
# [train] loss: 2.9960, acc: 4.71
# [test] loss: 3.0008, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.57it/s]
# 100% 5/5 [00:00<00:00, 31.70it/s]
# 8/50 - 16.00%
# [train] loss: 2.9957, acc: 5.02
# [test] loss: 3.0008, acc: 2.78
# 100% 41/41 [00:04<00:00,  9.51it/s]
# 100% 5/5 [00:00<00:00, 31.89it/s]
# 9/50 - 18.00%
# [train] loss: 2.9961, acc: 5.25
# [test] loss: 3.0014, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.46it/s]
# 100% 5/5 [00:00<00:00, 31.20it/s]
# 10/50 - 20.00%
# [train] loss: 2.9963, acc: 5.40
# [test] loss: 3.0016, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.04it/s]
# 100% 5/5 [00:00<00:00, 31.24it/s]
# 11/50 - 22.00%
# [train] loss: 2.9954, acc: 5.32
# [test] loss: 3.0014, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.37it/s]
# 100% 5/5 [00:00<00:00, 31.13it/s]
# 12/50 - 24.00%
# [train] loss: 2.9952, acc: 5.32
# [test] loss: 3.0019, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.33it/s]
# 100% 5/5 [00:00<00:00, 31.01it/s]
# 13/50 - 26.00%
# [train] loss: 2.9959, acc: 4.71
# [test] loss: 3.0019, acc: 2.08
# 100% 41/41 [00:04<00:00,  8.93it/s]
# 100% 5/5 [00:00<00:00, 31.18it/s]
# 14/50 - 28.00%
# [train] loss: 2.9956, acc: 5.09
# [test] loss: 3.0026, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.23it/s]
# 100% 5/5 [00:00<00:00, 29.64it/s]
# 15/50 - 30.00%
# [train] loss: 2.9960, acc: 5.71
# [test] loss: 3.0024, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.18it/s]
# 100% 5/5 [00:00<00:00, 30.54it/s]
# 16/50 - 32.00%
# [train] loss: 2.9955, acc: 5.02
# [test] loss: 3.0031, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.18it/s]
# 100% 5/5 [00:00<00:00, 30.34it/s]
# 17/50 - 34.00%
# [train] loss: 2.9957, acc: 4.86
# [test] loss: 3.0033, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.20it/s]
# 100% 5/5 [00:00<00:00, 30.36it/s]
# 18/50 - 36.00%
# [train] loss: 2.9958, acc: 4.63
# [test] loss: 3.0034, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.15it/s]
# 100% 5/5 [00:00<00:00, 30.47it/s]
# 19/50 - 38.00%
# [train] loss: 2.9956, acc: 5.09
# [test] loss: 3.0026, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.15it/s]
# 100% 5/5 [00:00<00:00, 30.33it/s]
# 20/50 - 40.00%
# [train] loss: 2.9955, acc: 5.09
# [test] loss: 3.0031, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.19it/s]
# 100% 5/5 [00:00<00:00, 31.02it/s]
# 21/50 - 42.00%
# [train] loss: 2.9953, acc: 4.48
# [test] loss: 3.0033, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.24it/s]
# 100% 5/5 [00:00<00:00, 30.79it/s]
# 22/50 - 44.00%
# [train] loss: 2.9954, acc: 5.86
# [test] loss: 3.0035, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 31.09it/s]
# 23/50 - 46.00%
# [train] loss: 2.9957, acc: 5.32
# [test] loss: 3.0038, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 31.13it/s]
# 24/50 - 48.00%
# [train] loss: 2.9958, acc: 5.40
# [test] loss: 3.0039, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.32it/s]
# 100% 5/5 [00:00<00:00, 31.21it/s]
# 25/50 - 50.00%
# [train] loss: 2.9960, acc: 4.63
# [test] loss: 3.0036, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.34it/s]
# 100% 5/5 [00:00<00:00, 31.07it/s]
# 26/50 - 52.00%
# [train] loss: 2.9955, acc: 5.17
# [test] loss: 3.0038, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.34it/s]
# 100% 5/5 [00:00<00:00, 31.02it/s]
# 27/50 - 54.00%
# [train] loss: 2.9956, acc: 4.78
# [test] loss: 3.0038, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.35it/s]
# 100% 5/5 [00:00<00:00, 31.15it/s]
# 28/50 - 56.00%
# [train] loss: 2.9959, acc: 5.32
# [test] loss: 3.0037, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.33it/s]
# 100% 5/5 [00:00<00:00, 31.09it/s]
# 29/50 - 58.00%
# [train] loss: 2.9954, acc: 5.25
# [test] loss: 3.0040, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.32it/s]
# 100% 5/5 [00:00<00:00, 31.17it/s]
# 30/50 - 60.00%
# [train] loss: 2.9957, acc: 5.09
# [test] loss: 3.0039, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.33it/s]
# 100% 5/5 [00:00<00:00, 31.31it/s]
# 31/50 - 62.00%
# [train] loss: 2.9955, acc: 5.25
# [test] loss: 3.0045, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.31it/s]
# 100% 5/5 [00:00<00:00, 31.34it/s]
# 32/50 - 64.00%
# [train] loss: 2.9958, acc: 5.56
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 31.11it/s]
# 33/50 - 66.00%
# [train] loss: 2.9956, acc: 5.56
# [test] loss: 3.0042, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.28it/s]
# 100% 5/5 [00:00<00:00, 30.86it/s]
# 34/50 - 68.00%
# [train] loss: 2.9959, acc: 5.40
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 31.10it/s]
# 35/50 - 70.00%
# [train] loss: 2.9958, acc: 6.10
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 30.79it/s]
# 36/50 - 72.00%
# [train] loss: 2.9958, acc: 5.02
# [test] loss: 3.0042, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.26it/s]
# 100% 5/5 [00:00<00:00, 30.82it/s]
# 37/50 - 74.00%
# [train] loss: 2.9955, acc: 5.40
# [test] loss: 3.0039, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.27it/s]
# 100% 5/5 [00:00<00:00, 30.75it/s]
# 38/50 - 76.00%
# [train] loss: 2.9953, acc: 5.02
# [test] loss: 3.0043, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.26it/s]
# 100% 5/5 [00:00<00:00, 30.83it/s]
# 39/50 - 78.00%
# [train] loss: 2.9959, acc: 5.63
# [test] loss: 3.0040, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.27it/s]
# 100% 5/5 [00:00<00:00, 29.96it/s]
# 40/50 - 80.00%
# [train] loss: 2.9956, acc: 5.48
# [test] loss: 3.0040, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 30.83it/s]
# 41/50 - 82.00%
# [train] loss: 2.9956, acc: 5.09
# [test] loss: 3.0040, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.29it/s]
# 100% 5/5 [00:00<00:00, 30.75it/s]
# 42/50 - 84.00%
# [train] loss: 2.9955, acc: 5.25
# [test] loss: 3.0037, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 30.89it/s]
# 43/50 - 86.00%
# [train] loss: 2.9958, acc: 4.63
# [test] loss: 3.0038, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 31.26it/s]
# 44/50 - 88.00%
# [train] loss: 2.9957, acc: 5.63
# [test] loss: 3.0040, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 30.56it/s]
# 45/50 - 90.00%
# [train] loss: 2.9952, acc: 5.40
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.31it/s]
# 100% 5/5 [00:00<00:00, 30.62it/s]
# 46/50 - 92.00%
# [train] loss: 2.9951, acc: 6.40
# [test] loss: 3.0042, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 30.69it/s]
# 47/50 - 94.00%
# [train] loss: 2.9959, acc: 5.32
# [test] loss: 3.0045, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.34it/s]
# 100% 5/5 [00:00<00:00, 30.68it/s]
# 48/50 - 96.00%
# [train] loss: 2.9960, acc: 4.48
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.32it/s]
# 100% 5/5 [00:00<00:00, 30.68it/s]
# 49/50 - 98.00%
# [train] loss: 2.9955, acc: 5.25
# [test] loss: 3.0041, acc: 2.08
# 100% 41/41 [00:04<00:00,  9.30it/s]
# 100% 5/5 [00:00<00:00, 31.01it/s]
# 50/50 - 100.00%
# [train] loss: 2.9958, acc: 5.02
# [test] loss: 3.0043, acc: 2.08
# best loss: 2.9985, best acc: 4.86, best index: 0
# log saved: GoogleNet_23-06-27_02-28-01.log
